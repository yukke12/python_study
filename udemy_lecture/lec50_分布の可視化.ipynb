# %%
from numpy.random import randn
import seaborn as sns
# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset)

# %%
sns.distplot(dataset, rug=True, hist=False) # rauplot

# %%
sns.distplot(dataset, bins = 25, kde_kws={'color' : 'indianred', 'label' : 'KDE PLOT'}, hist_kws={'color':'blue', 'label': 'HISTOGRAM'})

# %%
from pandas import Series

# %%
ser1 = Series(dataset, name = 'My_DATA')

# %%
ser1
# Out:
# 0     0.855930
# 1     0.869751
# 2    -0.074889
# 3     0.255961
# 4    -0.387189
# 5    -0.067595
# 6     0.042997
# 7     0.275233
# 8    -0.692991
# 9     0.012184
# 10    0.610613
# 11   -0.599193
# 12    0.778635
# 13    0.642526
# 14    0.166984
# ...
# 85   -2.293556
# 86    1.789549
# 87   -1.198334
# 88   -0.400908
# 89    0.050375
# 90   -0.713315
# 91    3.615411
# 92   -1.954340
# 93    1.338300
# 94   -2.366628
# 95    0.248158
# 96    0.316276
# 97    0.468859
# 98    0.699572
# 99    1.699629
# Name: My_DATA, Length: 100, dtype: float64

# %%
sns.distplot(ser1)
