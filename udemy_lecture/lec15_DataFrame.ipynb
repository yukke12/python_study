# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
nfl_frame = pd.read_clipboard()

# %% [markdown]
# ### クリップボードからDataFrameを作成
# [ここ](https://en.wikipedia.org/wiki/NFL_win%E2%80%93loss_records)　の表をコピー

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division
# 0       1,338  NFC North
# 1         850   NFC East
# 2       1,304  NFC North
# 3         768   AFC East
# 4         852   AFC East
# 5         970   NFC West

# %% [markdown]
# #### 列の名前取得

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season', 'Total Games', 'Division'], dtype='object')

# %%
nfl_frame['Team']
# Out:
# 0           Chicago Bears
# 1          Dallas Cowboys
# 2       Green Bay Packers
# 3          Miami Dolphins
# 4    New England Patriots
# 5     San Francisco 49ers
# Name: Team, dtype: object

# %%
nfl_frame.Team
# Out:
# 0           Chicago Bears
# 1          Dallas Cowboys
# 2       Green Bay Packers
# 3          Miami Dolphins
# 4    New England Patriots
# 5     San Francisco 49ers
# Name: Team, dtype: object

# %%
nfl_frame[['Team', 'First NFL Season']]
# Out:
#                    Team  First NFL Season
# 0         Chicago Bears              1920
# 1        Dallas Cowboys              1960
# 2     Green Bay Packers              1921
# 3        Miami Dolphins              1966
# 4  New England Patriots              1960
# 5   San Francisco 49ers              1950

# %% [markdown]
# ### カラムを絞って新しいデータフレーム作成

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season'])
# Out:
#                    Team  First NFL Season
# 0         Chicago Bears              1920
# 1        Dallas Cowboys              1960
# 2     Green Bay Packers              1921
# 3        Miami Dolphins              1966
# 4  New England Patriots              1960
# 5   San Francisco 49ers              1950

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season22'])
# Out:
#                    Team  First NFL Season22
# 0         Chicago Bears                 NaN
# 1        Dallas Cowboys                 NaN
# 2     Green Bay Packers                 NaN
# 3        Miami Dolphins                 NaN
# 4  New England Patriots                 NaN
# 5   San Francisco 49ers                 NaN

# %%
nfl_frame.head() #先頭5行取得
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
#
#   Total Games   Division
# 0       1,338  NFC North
# 1         850   NFC East
# 2       1,304  NFC North
# 3         768   AFC East
# 4         852   AFC East

# %%
nfl_frame.head(3)
# Out:
#    Rank               Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1      Chicago Bears  741   555    42  0.570              1920
# 1     2     Dallas Cowboys  480   364     6  0.568              1960
# 2     3  Green Bay Packers  720   547    37  0.566              1921
#
#   Total Games   Division
# 0       1,338  NFC North
# 1         850   NFC East
# 2       1,304  NFC North

# %%
nfl_frame.tail(3)
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games  Division
# 3         768  AFC East
# 4         852  AFC East
# 5         970  NFC West

# %%
nfl_frame.ix[3] # indexを使ってデータにアクセス
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            429
# Lost                           335
# Tied                             4
# Pct.                         0.561
# First NFL Season              1966
# Total Games                    768
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium" # 列に値を追加。

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division         Studium
# 0       1,338  NFC North  Levi's Stadium
# 1         850   NFC East  Levi's Stadium
# 2       1,304  NFC North  Levi's Stadium
# 3         768   AFC East  Levi's Stadium
# 4         852   AFC East  Levi's Stadium
# 5         970   NFC West  Levi's Stadium

# %%
nfl_frame = nfl_frame.rename(columns = {'Studium':'Stadium'}) # カラム名の変更

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division         Stadium
# 0       1,338  NFC North  Levi's Stadium
# 1         850   NFC East  Levi's Stadium
# 2       1,304  NFC North  Levi's Stadium
# 3         768   AFC East  Levi's Stadium
# 4         852   AFC East  Levi's Stadium
# 5         970   NFC West  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(6)

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division  Stadium
# 0       1,338  NFC North        0
# 1         850   NFC East        1
# 2       1,304  NFC North        2
# 3         768   AFC East        3
# 4         852   AFC East        4
# 5         970   NFC West        5

# %%
staduims = Series(["Levis's stadium", 'AT&T Stadium'], index=[4, 0])

# %%
staduims
# Out:
# 4    Levis's stadium
# 0       AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = staduims # Seriesを使って、値を更新

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division          Stadium
# 0       1,338  NFC North     AT&T Stadium
# 1         850   NFC East              NaN
# 2       1,304  NFC North              NaN
# 3         768   AFC East              NaN
# 4         852   AFC East  Levis's stadium
# 5         970   NFC West              NaN

# %%
del nfl_frame['Stadium'] # カラム削除

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1         Chicago Bears  741   555    42  0.570              1920
# 1     2        Dallas Cowboys  480   364     6  0.568              1960
# 2     3     Green Bay Packers  720   547    37  0.566              1921
# 3     4        Miami Dolphins  429   335     4  0.561              1966
# 4     5  New England Patriots  462   381     9  0.548              1960
# 5     6   San Francisco 49ers  520   436    14  0.543              1950
#
#   Total Games   Division
# 0       1,338  NFC North
# 1         850   NFC East
# 2       1,304  NFC North
# 3         768   AFC East
# 4         852   AFC East
# 5         970   NFC West

# %%
data = {'City':['SF', 'LA', 'NYC'], 'Population':[837000, 3880000, 8400000]}

# %%
data
# Out:
# {'Population': [837000, 3880000, 8400000], 'City': ['SF', 'LA', 'NYC']}

# %%
city_frame = DataFrame(data) # 辞書からDataFrameを作成

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
