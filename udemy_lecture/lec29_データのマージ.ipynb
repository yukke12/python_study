# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
dframe1 = DataFrame({'key' : ['X', 'Z', 'Y', 'Z' ,'X', 'X'], 'data_set_1' : np.arange(6)})

# %%
dframe1
# Out:
#    data_set_1 key
# 0           0   X
# 1           1   Z
# 2           2   Y
# 3           3   Z
# 4           4   X
# 5           5   X

# %%
dframe2 = DataFrame({'key' : ['Q', 'Y', 'Z'], 'data_set_2' : [1, 2, 3]})

# %%
dframe2
# Out:
#    data_set_2 key
# 0           1   Q
# 1           2   Y
# 2           3   Z

# %%
pd.merge(dframe1, dframe2) #mergeは、key同士をよしなにjoinする。
# Out:
#    data_set_1 key  data_set_2
# 0           1   Z           3
# 1           3   Z           3
# 2           2   Y           2

# %%
pd.merge(dframe1, dframe2, on='key') #onは、結合キーの指定
# Out:
#    data_set_1 key  data_set_2
# 0           1   Z           3
# 1           3   Z           3
# 2           2   Y           2

# %%
pd.merge(dframe1, dframe2, on = 'key', how = 'left') #結合方法の指定[left outer join]
# Out:
#    data_set_1 key  data_set_2
# 0           0   X         NaN
# 1           4   X         NaN
# 2           5   X         NaN
# 3           1   Z           3
# 4           3   Z           3
# 5           2   Y           2

# %%
pd.merge(dframe1, dframe2, on='key', how='right')
# Out:
#    data_set_1 key  data_set_2
# 0           1   Z           3
# 1           3   Z           3
# 2           2   Y           2
# 3         NaN   Q           1

# %%
pd.merge(dframe1, dframe2, on='key', how = 'outer')
# Out:
#    data_set_1 key  data_set_2
# 0           0   X         NaN
# 1           4   X         NaN
# 2           5   X         NaN
# 3           1   Z           3
# 4           3   Z           3
# 5           2   Y           2
# 6         NaN   Q           1

# %%
dframe3 = DataFrame({'key' : ['X', 'X', 'X', 'Y', 'Z', 'Z'], 'data_set3': range(6)})

# %%
dframe3
# Out:
#    data_set3 key
# 0          0   X
# 1          1   X
# 2          2   X
# 3          3   Y
# 4          4   Z
# 5          5   Z

# %%
dframe4 = DataFrame({'key' : ['Y', 'Y', 'X', 'X', 'Z'], 'data_set4': range(5)})

# %%
dframe4
# Out:
#    data_set4 key
# 0          0   Y
# 1          1   Y
# 2          2   X
# 3          3   X
# 4          4   Z

# %%
pd.merge(dframe3, dframe4)
# Out:
#    data_set3 key  data_set4
# 0          0   X          2
# 1          0   X          3
# 2          1   X          2
# 3          1   X          3
# 4          2   X          2
# 5          2   X          3
# 6          3   Y          0
# 7          3   Y          1
# 8          4   Z          4
# 9          5   Z          4

# %%
df_left = DataFrame({'key1': ['SF', 'SF', 'LA'], 'key2': ['one', 'two', 'one'], 'left_data' : [10, 20, 30]})

# %%
df_left
# Out:
#   key1 key2  left_data
# 0   SF  one         10
# 1   SF  two         20
# 2   LA  one         30

# %%
df_right = DataFrame({'key1': ['SF', 'SF', 'LA', 'LA'], 'key2': ['one', 'one', 'one', 'two'], 'right_data': [40, 50, 60, 70]})

# %%
df_right
# Out:
#   key1 key2  right_data
# 0   SF  one          40
# 1   SF  one          50
# 2   LA  one          60
# 3   LA  two          70

# %%
pd.merge(df_left, df_right , on=['key1', 'key2'], how= 'outer')
# Out:
#   key1 key2  left_data  right_data
# 0   SF  one         10          40
# 1   SF  one         10          50
# 2   SF  two         20         NaN
# 3   LA  one         30          60
# 4   LA  two        NaN          70

# %%
pd.merge(df_left, df_right, on='key1')
# Out:
#   key1 key2_x  left_data key2_y  right_data
# 0   SF    one         10    one          40
# 1   SF    one         10    one          50
# 2   SF    two         20    one          40
# 3   SF    two         20    one          50
# 4   LA    one         30    one          60
# 5   LA    one         30    two          70

# %%
pd.merge(df_left, df_right, on='key1', suffixes=['_left', '_right']) #suffixは、接尾辞を指定
# Out:
#   key1 key2_left  left_data key2_right  right_data
# 0   SF       one         10        one          40
# 1   SF       one         10        one          50
# 2   SF       two         20        one          40
# 3   SF       two         20        one          50
# 4   LA       one         30        one          60
# 5   LA       one         30        two          70
